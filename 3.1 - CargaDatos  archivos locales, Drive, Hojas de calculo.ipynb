# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %% [markdown]
# # Sección nueva

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-67edf6b2-da67-4791-a05a-36f0ba02e4e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67edf6b2-da67-4791-a05a-36f0ba02e4e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris.csv
# User uploaded file "iris.csv" with length 3716 bytes

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content Ejemplo 01 \n')
  f.write('some content Ejemplo 02 \n')

files.download('example.txt')

# %%
ls
# Out:
# example.txt  iris.csv  sample_data/

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/semanaTec/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/semanaTec/foo.txt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-fff6846b1f4f> in <module>
# ----> 1 with open('/content/drive/My Drive/semanaTec/foo.txt', 'w') as f:
#       2   f.write('Hello Google Drive!')
#       3 get_ipython().system('cat /content/drive/My\\ Drive/semanaTec/foo.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/semanaTec/foo.txt'

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: 2.2 - Git en colaboratory.ipynb, id: 18IYT95mNh78gr0KvmxWPZ-V17Dku8SBq
# title: SemanaTec, id: 1AmWwmaAKRw9m9xwgMtOxsCAcOlCk6OXO
# title: arte-analitica, id: 1K9cZeQdHJIColkbxOgaTulBIz_IOLl2T
# title: credenciales.json, id: 1-eldT8jvyN0g3TKay0Yin5qYW-TSozG5
# title: Un Mundo bipolar, id: 13FOuAwyZh_XIM6yz6lyFyxW5XOm-P5rIYe7vmuox1p8
# title: Actividad 8 Equipo 21, id: 1ZLw5EQCXwtnxUz9LJ656DjNhC6xUzXeQvpqWSI1Qppo
# title: EBSCO, id: 1ccMb2ubpI6mnq3kCv_GoV3qdNXtMiXHB
# title: A01236331_Video.mp4, id: 173OcknOFU8Dt7dbcl2R8U6yanEJwnZAV
# title: class_diagram.png, id: 1euokt6YDwkltfnpCQ9WpnVdWl5_25kQV
# title: Compilation Overload.drawio, id: 1xgCoDUQ75RSV0CBwl8qFuNtgCeaGfp_f
# title: A01236331_RaúlKenyuMedinaTakada_EAO_F1014B.mp4, id: 16B8toQoZ44RSAzvMq10TLPHykzEd92vB
# title: Documentación de la regresión lineal, id: 1Wp36NAaRyG2ytmWYdhGuBo07yKUvEiWFTDcZCqdFqS0
# title: video2684221229.mp4, id: 14Ilt2Mme0gFsofU1qhkTj8hDKXhAw2mK
# title: The Rise of COVSAR, id: 1K-j1g9xckKhUTSeIGyZ6W57xIVHQhB5WS742BBD2hGc
# title: Doc de Runge Kutta 4 diferencial 2do orden, id: 1iwGKO3Ujtpj0YgIInBICYYs-H6rJDFxSKBW3ShEJQu0
# title: Actividad_colaborativa_Faraday.docx, id: 1_l4pxNfJ9cn9a0zTAJAEBTx-pRAvioPV
# title: Apocalypse narratives, id: 1nnzgueJgPdfWijWIM4_mHSs5Z8n3jqt6Ji6TEUayHv8
# title: Hoja de cálculo sin título, id: 134xiuvi8PSctIDY_K5Vqq6H5htX5WGXdtq0kzO3wYAE
# title: Myths and rituals, id: 1TQnykiltV_nItER26QIo2PJiU8APfHDG5j1rYwgPywo
# title: Documento sin título, id: 1BvpEuhHtW-MHRVhXZkWdRr_VWv719maNAkmq0VQNZ48
# title: Rites of passage, id: 1jJPcAP8d9Vhh_a9UVB8q9iB-mpfKEUIN2--7EueQnHc
# title: GuiaEntregable3, id: 1FSpywcEM-oe-P_lLUyrKAh3WnyhKH3MGhKH3VUos5_U
# title: GuiaEntregable3.pdf, id: 1JOU8U5WzWwdcPy6jXQKRVkyNwQ5X_GUG
# title: Int de línea , id: 1d5S7CMedTMpzI1RQRSx2cnJg83RwYnfWThjukq1VcOA
# title: Documento sin título, id: 19khd0z9jpfnK8gG8rjy4A5Q01daVk_kq3usUguhM8_E
# title: Int de línea .pdf, id: 1idZ2UA4EIqZYd9PsU3Q4U_vIDm1yyfOi
# title: Ragnarök_Kenyu Medina, id: 1Naiimo3S_uiSSjqzhtuSCpRbr6ZEV5rLU2K529YP1T8
# title: Reto-Entregable1_F1013B, id: 1gBz9jHXuMOKziSZpVCDN2G_-QkaY8SDyRhf5_cztGwo
# title: Reto-Entregable1_F1013B.pdf, id: 1-lekyZI2198kQLAvno9dlWvUn7s3poZT
# title: Reto-Entregable1_F1013B.pdf, id: 1iDWkKDrg5kfeICi3toVME4ZMkRNWJBk5
# title: Evidencia_A01236331.mp4, id: 1qbUdFfVa0uPb24aDqPS8-z9M0lRqh9k2
# title: Video Mariotte.mp4, id: 178M5r2SpCLV--8cATVCWmxRq3b3Loqwk
# title: WIN_20220314_22_25_16_Pro.mp4, id: 1RaJAKpdYGSdNNyU60neiCYpRWJt-Oubx
# title: Experimento1 FJ22, id: 1Md18xxN_0f7hOpiCfdKjINiotwjkwoJXkY18j8mdOFc
# title: Actividad-Jenga 2022, id: 167TKsYuOk8wrXKQmc1MB9HJ_5xZyE0U3h7-3wVNSwzQ
# title: Tarea 3 - A01236331, id: 1cOFu0lCjI4iLjOCKh1rnnRkN-4rx9hMN4wObVJYCLoc
# title: TC1003B FJ2002 Tarea 3-1.pdf, id: 1_9XZ7c7PvzTMS5MkhfpY3XmXpu4rkq1d
# title: Tarea 2 - A01236331, id: 1qtZwlx9h3UFaWTfPkfqVx3redcN_AAyfIohUcz2ub5A
# title: Documento sin título, id: 17wpwr2jIhY8PudujkhEfPHHzj6yKMbeA0CrOzzD9MFc
# title: TC1003B FJ2002 Tarea 2.pdf, id: 1262hHn4NmCjFbLhKgtTWhg9ARTmKkr_p
# title: Tarea 1 - A01236331, id: 1bh-bGnuBgJpzBg45oyDz46v9t8JBV337lyktLn84hQw
# title: TC1003B FJ2002 Tarea 1.pdf, id: 1wMN6l8dUv1nkWGShy1LkcSksrtqTtIS7
# title: TC1003B FJ2002 Tarea 1.pdf, id: 1Ve8hs7_mtzJ-HdQ0GvQ6juMQS6FvAajE
# title: PracticaTiroParabolicoTracker, id: 1-5O2RQ7aFhU-34WIc5Ma-OjLCUYTmLrMwWdgHOO6jME
# title: Sentido de identidad, id: 1TVM40xKFnNaT5_v2sNl7EVsAb34TKXH6No4KgfsGVGY
# title: Copia de Programming Lesson by Slidesgo, id: 1FMr9BUsYdbt9x4SPmSkvMI-3RpwJpEWKX2QheEb6RkY
# title: Exposición-A01236331Kenyu.mp4, id: 1cp767VwPdfa4hK6UUXWrFaytPtOl08IA
# title: A01236331_quiz_1, id: 1MUoakx2kcWZv95QT_BEcii0Fq27IEmIvSGxJPfqbjIA
# title: ReporteEtapa2Fisica-Equipo#6, id: 1KVlKvIvaUcNT2ANPq3QJJc7WaALsuH2q-Q9COozfH1k
# title: SegundaEntrega_Situación problema, id: 1Wl3za4qd8i2gy_tasBbpKC61MJi70RqoHCgky9VmFzo
# title: Avances Equipo6, id: 1vvxwOx0qBskgEzLHOBED1DSS9z4uVKCee4nB4P1Wwyw
# title: Evidencia Fase 1.mp4, id: 1bBU_8XhC1QF3RmXFKuQN2INWYJyp_EuZ
# title: Desperdicio de comida, id: 1YI-mNdqgwb7UvHQwN85WOnSaM_zuhJuZaubm5mau8UA
# title: Evidencia 1 El Mundo Desigual.pdf, id: 1OCFGbbE-_ARBMsvWfkavLeCdo6UYfnm6
# title: PRACTICATiempoReaccionTec21-1.pdf, id: 1-lEfC0V9_3wSNiKMuu3eqs9rRuG54B8I
# title: Conceptos_básicos, id: 14cthAFSO_WPSA_3OmaITJIX7ErN7Fr-pXrceEY2Uy_c
# title: Reto 1 Equipo 5, id: 1Btck0uEJXf1Gl67P6lshPZCz7B-bXVhZh9MxHWeuK1A

# %%
fid= '1r3STNnFiq8uRhifgq96dbO2keF58zFqU'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'Sample upload.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# ---------------------------------------------------------------------------
# ResumableUploadError                      Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in _FilesInsert(self, param)
#     368       metadata = self.auth.service.files().insert(**param).execute(
# --> 369         http=self.http)
#     370     except errors.HttpError as error:
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     878             while body is None:
# --> 879                 _, body = self.next_chunk(http=http, num_retries=num_retries)
#     880             return body
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/http.py in next_chunk(self, http, num_retries)
#     998             else:
# --> 999                 raise ResumableUploadError(resp, content)
#    1000         elif self._in_error_state:
#
# ResumableUploadError: <HttpError 404 when requesting None returned "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU". Details: "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU">
#
# During handling of the above exception, another exception occurred:
#
# ApiRequestError                           Traceback (most recent call last)
# <ipython-input-24-6e0aaba0a3fb> in <module>
#       1 uploaded = drive.CreateFile({'title': 'Sample upload.txt','parents':[{"id":fid}]})
#       2 uploaded.SetContentString('Sample upload file content')
# ----> 3 uploaded.Upload()
#       4 print('Uploaded file with ID {}'.format(uploaded.get('id')))
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in Upload(self, param)
#     283         self._FilesPatch(param=param)
#     284     else:
# --> 285       self._FilesInsert(param=param)
#     286
#     287   def Trash(self, param=None):
#
# /usr/local/lib/python3.7/dist-packages/pydrive/auth.py in _decorated(self, *args, **kwargs)
#      73       self.http = self.auth.Get_Http_Object()
#      74
# ---> 75     return decoratee(self, *args, **kwargs)
#      76   return _decorated
#      77
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in _FilesInsert(self, param)
#     369         http=self.http)
#     370     except errors.HttpError as error:
# --> 371       raise ApiRequestError(error)
#     372     else:
#     373       self.uploaded = True
#
# ApiRequestError: <HttpError 404 when requesting None returned "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU". Details: "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU">

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# ---------------------------------------------------------------------------
# FileNotUploadedError                      Traceback (most recent call last)
# <ipython-input-17-cb54954b159a> in <module>
#       1 downloaded = drive.CreateFile({'id': uploaded.get('id')})
# ----> 2 print('Downloaded content "{}"'.format(downloaded.GetContentString()))
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in GetContentString(self, mimetype, encoding, remove_bom)
#     191                     type(self.content) is not io.BytesIO or \
#     192                     self.has_bom == remove_bom:
# --> 193       self.FetchContent(mimetype, remove_bom)
#     194     return self.content.getvalue().decode(encoding)
#     195
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in _decorated(self, *args, **kwargs)
#      40   def _decorated(self, *args, **kwargs):
#      41     if not self.uploaded:
# ---> 42       self.FetchMetadata()
#      43     return decoratee(self, *args, **kwargs)
#      44   return _decorated
#
# /usr/local/lib/python3.7/dist-packages/pydrive/auth.py in _decorated(self, *args, **kwargs)
#      73       self.http = self.auth.Get_Http_Object()
#      74
# ---> 75     return decoratee(self, *args, **kwargs)
#      76   return _decorated
#      77
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in FetchMetadata(self, fields, fetch_all)
#     242         self.UpdateMetadata(metadata)
#     243     else:
# --> 244       raise FileNotUploadedError()
#     245
#     246   @LoadMetadata
#
# FileNotUploadedError:

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('HojaClaseEjemplo')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('HojaClaseEjemplo').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1i0vEPyJqXq9IbQ8EvH1B_jVWSQs9Ca_fwWbfXXgvC40',
#  'updatedRange': "'Hoja 1'!A1:C2",
#  'updatedRows': 2,
#  'updatedColumns': 3,
#  'updatedCells': 6}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('HojaClaseEjemplo').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['10', '6', '9'], ['2', '1', '5']]
# ******************Data Frame*********************
#     0  1  2
# 0  10  6  9
# 1   2  1  5
